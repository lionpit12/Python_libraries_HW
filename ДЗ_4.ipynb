# %%
# ДЗ к Видео Уроку № 4

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
x=[1, 2, 3, 4, 5, 6, 7]
y=[3.5, 3.8, 4.2, 4.5, 5, 5.5, 7.]
plt.figure(figsize=(9,5))
plt.plot(x, y, c='g',lw=3)
plt.show()

# %%
plt.figure(figsize=(9,5))
plt.scatter(x, y, c='black')
plt.show()

# %%
# Задание 2

# %%
t=np.linspace(0,10,51)
t
# Out:
# array([ 0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,  1.4,  1.6,  1.8,  2. ,
#         2.2,  2.4,  2.6,  2.8,  3. ,  3.2,  3.4,  3.6,  3.8,  4. ,  4.2,
#         4.4,  4.6,  4.8,  5. ,  5.2,  5.4,  5.6,  5.8,  6. ,  6.2,  6.4,
#         6.6,  6.8,  7. ,  7.2,  7.4,  7.6,  7.8,  8. ,  8.2,  8.4,  8.6,
#         8.8,  9. ,  9.2,  9.4,  9.6,  9.8, 10. ])

# %%
f=[np.cos(i) for i in t]

# %%
plt.figure(figsize=(12,6))
plt.plot(t, f, c='g',lw=3,label='График f(t)', ls='--')
plt.title('График f(t)')
plt.xlabel('Значения t')
plt.ylabel('Значения f')
plt.axis([0.5, 9.5, -2.5, 2.5])
plt.show()

# %%
# *Задание 3

# %%
x=np.linspace(-3,3,51)

# %%
y1 = x**2
y2 = 2 * x + 0.5
y3 = -3 * x - 1.5
y4 = [np.sin(i) for i in x]

# %%
fig,ax=plt.subplots(2,2)
ax1, ax2, ax3, ax4 = ax.flatten()

fig.set_size_inches(8, 6)
fig.subplots_adjust(wspace=0.3, hspace=0.3)

ax1.plot(x, y1, ls='--')
ax2.plot(x, y2, c='g')
ax3.plot(x, y3, c='black')
ax4.plot(x, y4, c='y')

ax1.plot(x, y1)
ax1.set_title("График y1")

ax2.plot(x, y2)
ax2.set_title("График y2")

ax3.plot(x, y3)
ax3.set_title("График y3")

ax4.plot(x, y4)
ax4.set_title("График y4")

ax1.plot(x, y1)
ax1.set_xlim([-5, 5])

plt.show()

# %%
# *Задание 4

# %%
data=pd.read_csv(r'C:\Users\sunne\OneDrive\Desktop\Python\ДЗ Python\creditcard.csv', sep=',')
data.head(4)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
plt.style.use('fivethirtyeight')

# %%
data['Class'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['Class'].value_counts().plot(kind='bar',logy=True)
# Out:
# <AxesSubplot:>

# %%
a=data.loc[(data["Class"] == 0), "V1"]
b=data.loc[(data["Class"] == 1), "V1"]

# %%
plt.figure(figsize=(12,8))
plt.hist(a, bins=20, alpha=0.5,color="lightgrey",label='Good')
plt.hist(b, bins=20, alpha=0.5,color="red",label='Bad')
plt.axis([-50, 20, 0, 200])
plt.legend(loc="upper left")

plt.show()
